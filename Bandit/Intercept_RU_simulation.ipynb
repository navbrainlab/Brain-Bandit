# %%
import pandas as pd
import numpy as np
from statsmodels.discrete.discrete_model import Probit
from statsmodels.discrete.discrete_model import  Logit
from statsmodels.regression.mixed_linear_model import MixedLM
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sn
plt.style.use('default')
def standardization(data):
    data = np.array(data)
    mu = np.mean(data, axis=0)
    print(mu)
    sigma = np.std(data, axis=0)
    print(sigma)
    return (data ) / (sigma + 1e-9)


def plot_logit(w=None, b=None, label=None):
    x = np.arange(-1.5,1.5,0.05)
    y = 1. / (1+np.exp(-(x*w + b)))
    plt.plot(x, y, label=label)
    # plt.show()

if __name__ == '__main__':

    TU = 2.5
    r1_var_list = [2.25,2.,1.75,1.5,1.25]
    n = len(r1_var_list)
    modes = ['seeking','neutral','averse']
    labels = ['optimistic', 'neutral','conservative']
    fmts = ['o-', 's-', 'v-']
    for i,mode in enumerate(modes):
        b_list = []
        b_std_list = []
        w_list = []
        w_std_list = []
        RU_list = []
        for (index, r1_var) in enumerate(r1_var_list):
            r1_std = np.sqrt(r1_var)
            r2_std = np.sqrt(TU - r1_var)
            RU = r1_std - r2_std
            p_list_combined = []
            for times in range(10):
                p_list = np.load(f'saved/simulation_TU={TU}_var={r1_var}_{mode}_{times}_n=2.npy')
                p_list = p_list[np.newaxis, :]
                if times == 0:
                    p_list_combined = p_list
                else:
                    p_list_combined = np.concatenate([p_list_combined, p_list], axis=0)
            p_mean = np.mean(p_list_combined, axis=0)
            p_std = np.std(p_list_combined, axis=0)

            V_list = np.arange(-1.5, 1.5, 0.05)
            X = np.array(V_list).T
            X = pd.DataFrame(X, columns=['V'])
            X = sm.add_constant(X)
            Y = p_mean
            model = Logit(Y, X)
            # model = MixedLM(Y, X)
            Logit_model = model.fit()
            v = Logit_model.params['V']
            v_std = Logit_model.bse['V']
            const = Logit_model.params['const']
            const_std = Logit_model.bse['const']
            b_list.append(const)
            b_std_list.append(const_std)
            w_list.append(v)
            w_std_list.append(v_std)
            RU_list.append(RU)
            print(Logit_model.summary())
            # plot_logit(v, const, label=f'{RU}')

        # plt.plot(RU_list, b_list, label='bias')
        plt.errorbar(RU_list, b_list,fmt=fmts[i],elinewidth=2,capsize=5, label=labels[i])
        # plt.title(f'{mode}')
    plt.xlabel('relative uncertainty', size=20)
    plt.ylabel('intercept', size=20)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.ylim(-4,4)
    # plt.legend(prop={'size': 13})
    plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.083726
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8732
# Time:                        14:46:57   Log-Likelihood:                -5.0236
# converged:                       True   LL-Null:                       -39.632
# Covariance Type:            nonrobust   LLR p-value:                 8.824e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3393      1.396      2.392      0.017       0.603       6.075
# V              8.8712      3.260      2.721      0.006       2.482      15.260
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.30 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.079451
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8821
# Time:                        14:46:57   Log-Likelihood:                -4.7671
# converged:                       True   LL-Null:                       -40.435
# Covariance Type:            nonrobust   LLR p-value:                 3.015e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7859      1.256      2.219      0.027       0.325       5.247
# V              9.3842      3.545      2.647      0.008       2.436      16.332
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.30 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.081828
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8806
# Time:                        14:46:57   Log-Likelihood:                -4.9097
# converged:                       True   LL-Null:                       -41.120
# Covariance Type:            nonrobust   LLR p-value:                 1.738e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8041      0.952      1.895      0.058      -0.062       3.670
# V              9.1082      3.389      2.687      0.007       2.465      15.751
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.30 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.085961
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8757
# Time:                        14:46:57   Log-Likelihood:                -5.1577
# converged:                       True   LL-Null:                       -41.488
# Covariance Type:            nonrobust   LLR p-value:                 1.540e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9262      0.745      1.243      0.214      -0.534       2.386
# V              8.8041      3.221      2.733      0.006       2.491      15.117
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.43 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.084048
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8787
# Time:                        14:46:57   Log-Likelihood:                -5.0429
# converged:                       True   LL-Null:                       -41.581
# Covariance Type:            nonrobust   LLR p-value:                 1.247e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0232      0.670      0.035      0.972      -1.290       1.337
# V              8.9791      3.317      2.707      0.007       2.477      15.481
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.40 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.096268
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8611
# Time:                        14:46:57   Log-Likelihood:                -5.7761
# converged:                       True   LL-Null:                       -41.582
# Covariance Type:            nonrobust   LLR p-value:                 2.621e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0282      0.621      0.045      0.964      -1.189       1.246
# V              7.7175      2.644      2.919      0.004       2.535      12.900
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.23 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.091582
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8678
# Time:                        14:46:57   Log-Likelihood:                -5.4949
# converged:                       True   LL-Null:                       -41.580
# Covariance Type:            nonrobust   LLR p-value:                 1.974e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0135      0.637      0.021      0.983      -1.235       1.262
# V              8.1091      2.848      2.848      0.004       2.528      13.690
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.27 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.084876
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8775
# Time:                        14:46:57   Log-Likelihood:                -5.0926
# converged:                       True   LL-Null:                       -41.579
# Covariance Type:            nonrobust   LLR p-value:                 1.315e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0023      0.668     -0.003      0.997      -1.312       1.307
# V              8.9240      3.287      2.715      0.007       2.482      15.366
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.32 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.075483
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8911
# Time:                        14:46:57   Log-Likelihood:                -4.5290
# converged:                       True   LL-Null:                       -41.583
# Covariance Type:            nonrobust   LLR p-value:                 7.399e-18
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0469      0.701      0.067      0.947      -1.327       1.421
# V              9.8239      3.796      2.588      0.010       2.384      17.264
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.25 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.071546
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8968
# Time:                        14:46:57   Log-Likelihood:                -4.2928
# converged:                       True   LL-Null:                       -41.583
# Covariance Type:            nonrobust   LLR p-value:                 5.822e-18
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0576      0.727      0.079      0.937      -1.368       1.483
# V             10.5697      4.236      2.495      0.013       2.267      18.873
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.17 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.085668
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8687
# Time:                        14:46:57   Log-Likelihood:                -5.1401
# converged:                       True   LL-Null:                       -39.140
# Covariance Type:            nonrobust   LLR p-value:                 1.634e-16
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2141      1.348     -2.385      0.017      -5.855      -0.573
# V              8.7607      3.200      2.738      0.006       2.489      15.033
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.25 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.081087
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8782
# Time:                        14:46:57   Log-Likelihood:                -4.8652
# converged:                       True   LL-Null:                       -39.941
# Covariance Type:            nonrobust   LLR p-value:                 5.491e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.7417      1.228     -2.232      0.026      -5.149      -0.335
# V              9.1791      3.430      2.676      0.007       2.457      15.902
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.28 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.081800
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8796
# Time:                        14:46:57   Log-Likelihood:                -4.9080
# converged:                       True   LL-Null:                       -40.769
# Covariance Type:            nonrobust   LLR p-value:                 2.478e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8679      0.972     -1.922      0.055      -3.773       0.037
# V              9.1645      3.421      2.679      0.007       2.459      15.870
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.27 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.086375
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8746
# Time:                        14:46:58   Log-Likelihood:                -5.1825
# converged:                       True   LL-Null:                       -41.330
# Covariance Type:            nonrobust   LLR p-value:                 1.852e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8990      0.737     -1.220      0.223      -2.344       0.546
# V              8.7230      3.177      2.746      0.006       2.497      14.949
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.28 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.087887
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                          Logit   Df Residuals:                       58
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.8732
# Time:                        14:46:58   Log-Likelihood:                -5.2732
# converged:                       True   LL-Null:                       -41.582
# Covariance Type:            nonrobust   LLR p-value:                 1.574e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0341      0.655      0.052      0.958      -1.250       1.318
# V              8.5770      3.097      2.769      0.006       2.507      14.647
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.33 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
