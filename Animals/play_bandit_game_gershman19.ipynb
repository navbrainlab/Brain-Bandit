# %%
import sys
sys.path.append('..')
import numpy as np
import pandas as pd
from model.Lyapunov_Worm_deconstruction import Lyapunov_Worm_Deconstruction
from Bandit.Expected_Value import CalculateMeanValue
from Bandit.BanditGame import Play
from tqdm import tqdm
from multiprocessing import  Process

# %%
dim = 2
varargin = {
    'step': 400,  # how many steps to run the brain circuit before executing the next movement
    'tau': np.ones(dim),  # decay time constant
    'weights_in': np.ones(dim) * 1.,  # input weights
    'rs': np.ones(dim) * .5,  #
    'w': np.ones(dim) * 4,  # weight of mutual inhibition
    'k': 7. * np.ones(dim),  # sigmoid center
    'n': 1.5 * np.ones(dim),  # sigmoid slope
    'bi': np.ones(dim) * 6.15,  # baseline production
    'dt': 1.2,  # size of timesteps
    'nsf': 1.15,  # noise level
    'w_avg_comp': 1. / 40.,
    'w_std_comp': 1. / 4. * 1.3
}
# seed = 1
# np.random.seed(seed)

conds = [ 'RR','SS','RS','SR']
bandit_std_dict = {
    'RR': [4., 4.],
    'SS': [0., 0.],
    'RS': [4., 0.],
    'SR': [0., 4.]
}
def Play_bandit(cond):
    bandit_std_list = bandit_std_dict[cond]
    prior = None
    raw_path = f'bandit_data/raw_{dim}D_Gershman_' + cond + '4.csv'
    analysis_path = f'bandit_data/analysed_{dim}D_Gershman_' + cond + '4.csv'
    p = Play(varargin=varargin, dim=dim, net='deconstruction',force_times=2, prior=prior, init=True, bandit_mean=0, mean_std=10,
             bandit_std_list=bandit_std_list, subject=1, block=8000, trial=20, save=True, save_path=raw_path,
             save_mode='w')
    p.play()
    k = CalculateMeanValue(raw_path, analysis_path, trial=20, dim=dim, prior=prior)
    k.run()
    
process_list = []
for cond in conds:
    p = Process(target=Play_bandit,args=(cond,))
    p.start()
    process_list.append(p)

for i in process_list:
    p.join()
# Out:
#   0%|          | 0/8000 [00:00<?, ?it/s]/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reward_history = np.array(reward_history)
# /home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reward_history = np.array(reward_history)
# /home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reward_history = np.array(reward_history)
# /home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reward_history = np.array(reward_history)
#   1%|          | 43/8000 [00:06<19:19,  6.86it/s]
#
#
#
# Process Process-3:
# Process Process-4:
# Process Process-2:
# Process Process-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_96515/129956675.py", line 34, in Play_bandit
#     p.play()
#   File "/home/ubuntu/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_96515/129956675.py", line 34, in Play_bandit
#     p.play()
#   File "/tmp/ipykernel_96515/129956675.py", line 34, in Play_bandit
#     p.play()
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 108, in play
#     result_list = self.one_game(dim=self.dim,game=game, block_index=i)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 108, in play
#     result_list = self.one_game(dim=self.dim,game=game, block_index=i)
#   File "/tmp/ipykernel_96515/129956675.py", line 34, in Play_bandit
#     p.play()
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 108, in play
#     result_list = self.one_game(dim=self.dim,game=game, block_index=i)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 90, in one_game
#     choice = net.decide(history=reward_history,init=self.init)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 90, in one_game
#     choice = net.decide(history=reward_history,init=self.init)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 59, in decide
#     dxs, nxs = self.bmfun(neural_inputs_mean=neural_input, neural_state=neuro_state)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 108, in play
#     result_list = self.one_game(dim=self.dim,game=game, block_index=i)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 59, in decide
#     dxs, nxs = self.bmfun(neural_inputs_mean=neural_input, neural_state=neuro_state)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 90, in one_game
#     choice = net.decide(history=reward_history,init=self.init)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 86, in bmfun
#     all_effects = np.sum(self.w * self.sig(neural_state))
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/Bandit/BanditGame.py", line 90, in one_game
#     choice = net.decide(history=reward_history,init=self.init)
# KeyboardInterrupt
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 87, in bmfun
#     big_nxs = (-(all_effects-self.w*self.sig(neural_state)) + self.bi + neural_inputs_mean) / self.rs
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 59, in decide
#     dxs, nxs = self.bmfun(neural_inputs_mean=neural_input, neural_state=neuro_state)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 59, in decide
#     dxs, nxs = self.bmfun(neural_inputs_mean=neural_input, neural_state=neuro_state)
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 72, in sig
#     return 1. / (1 + np.exp(-self.n * (x - self.k)))
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 87, in bmfun
#     big_nxs = (-(all_effects-self.w*self.sig(neural_state)) + self.bi + neural_inputs_mean) / self.rs
# KeyboardInterrupt
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 72, in sig
#     return 1. / (1 + np.exp(-self.n * (x - self.k)))
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 86, in bmfun
#     all_effects = np.sum(self.w * self.sig(neural_state))
# KeyboardInterrupt
#   File "/home/ubuntu/PycharmProjects/Brain-Bandit/model/Lyapunov_Worm_deconstruction.py", line 72, in sig
#     return 1. / (1 + np.exp(-self.n * (x - self.k)))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 45
#      42     process_list.append(p)
#      44 for i in process_list:
# ---> 45     p.join()
#
# File ~/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/popen_fork.py:47, in Popen.wait(self, timeout)
#      45             return None
#      46     # This shouldn't block if wait() returned successfully.
# ---> 47     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      48 return self.returncode
#
# File ~/anaconda3/envs/banditnet/lib/python3.8/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError as e:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:
