# %%
import pandas as pd
import numpy as np
from statsmodels.discrete.discrete_model import Probit
from statsmodels.regression.mixed_linear_model import MixedLM
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sn
plt.style.use('default')
def standardization(data):
    data = np.array(data)
    mu = np.mean(data, axis=0)
    print(mu)
    sigma = np.std(data, axis=0)
    print(sigma)
    return (data ) / (sigma + 1e-9)


if __name__ == '__main__':

    conditions = ['RS','SR','RR','SS']
    const_list = []
    v_list = []
    std_const_list = []
    std_v_list = []
    # ori_list = [2.1702, 2.177, 2.0738, 2.5492,1.7513,1.852,1.7582,2.0644,1.1225,1.0966,1.122,1.511]
    ori_list = [0.0039548, 0.035103, 0.11163, -0.038259, -0.066627, -0.19945, -0.015113,0.025406,-0.063868,-0.014029,-0.0038405,-0.024054]
    ori_list_std = [0.026212,0.024205,0.047888,0.027847,0.021859,0.044628,0.022431,0.019441,0.031009,0.024677,0.020202,0.036573]
    fit_list = []
    fit_std_list = []
    colors = ['salmon', 'royalblue', 'goldenrod']
    for cond in conditions:
        path_list = [f'/home/ubuntu/PycharmProjects/Brain-inspired-Exploration/Brain-inspired-Exploration/Data_fitting/human_data_fan23/saved/analysed_2D_fan_' + cond + 'high2.csv',f'/home/ubuntu/PycharmProjects/Brain-inspired-Exploration/Brain-inspired-Exploration/Data_fitting/human_data_fan23/saved/analysed_2D_fan_'+cond+'low2.csv',f'/home/ubuntu/PycharmProjects/Brain-inspired-Exploration/Brain-inspired-Exploration/Data_fitting/human_data_gershman19/saved/analysed_2D_Gershman_'+cond+'4.csv']
        for path in path_list:
            Data = pd.read_csv(path)
            print(Data.shape)
            Data['choice'] = Data['choice'] & 1
            Data = Data[Data.trial > 4]
            Data = Data[Data.trial < 15]
            C_list = Data['choice'].tolist()
            Y = C_list
            V_list = (Data['Q0']-Data['Q1']).tolist()
            V_list = standardization(V_list)
            X = np.array(V_list).T
            X = pd.DataFrame(X, columns=['V'])
            X = sm.add_constant(X)
            model = Probit(Y, X)
            probit_model = model.fit()
            const = probit_model.params['const']
            v = probit_model.params['V']
            std_const = probit_model.params['const'] - probit_model.conf_int()[0]['const']
            std_v = probit_model.params['V'] - probit_model.conf_int()[0]['V']
            std_const_list.append(std_const)
            std_v_list.append(std_v)
            print(probit_model.summary())
            fit_list.append(const)
            fit_std_list.append(std_const)

    plt.errorbar(fit_list[::3], ori_list[::3], xerr=fit_std_list[::3], yerr=ori_list_std[::3], fmt='o', capsize=4,
                 capthick=2, color=colors[0], label='Fan23_high_anxiety')
    plt.errorbar(fit_list[1::3], ori_list[1::3], xerr=fit_std_list[1::3], yerr=ori_list_std[1::3], fmt='o', capsize=4,
                 capthick=2, color=colors[1], label='Fan23_low_anxiety')
    plt.errorbar(fit_list[2::3], ori_list[2::3], xerr=fit_std_list[2::3], yerr=ori_list_std[2::3], fmt='o', capsize=4,
                 capthick=2, color=colors[2], label='Gershman19')
    plt.ylabel('Human',size=20)
    plt.xlabel('Model',size=20)
    plt.ylim([-0.25,0.18])
    plt.xlim([-0.25, 0.18])
    
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    ax=plt.gca()
    locator = plt.MultipleLocator(0.1)
    ax.xaxis.set_major_locator(locator)
    plt.plot([-10, 10], [-10, 10], color='k', linestyle='--', linewidth=0.8)
    plt.title('intercept',size=20)
    plt.legend(prop={'size': 15})
    plt.show()
# Out:
# (400000, 12)
# -0.0803663195
# 14.434345428514414
# Optimization terminated successfully.
#          Current function value: 0.296950
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5716
# Time:                        14:42:33   Log-Likelihood:                -59390.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0153      0.004      3.701      0.000       0.007       0.023
# V              2.1920      0.009    243.221      0.000       2.174       2.210
# ==============================================================================
# (400000, 12)
# -0.24231898800000007
# 14.397306116449156
# Optimization terminated successfully.
#          Current function value: 0.338342
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5119
# Time:                        14:42:34   Log-Likelihood:                -67668.
# converged:                       True   LL-Null:                   -1.3862e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0418      0.004     10.792      0.000       0.034       0.049
# V              1.8340      0.007    250.443      0.000       1.820       1.848
# ==============================================================================
# (160000, 12)
# -0.194083945
# 14.24772848854713
# Optimization terminated successfully.
#          Current function value: 0.468845
#          Iterations 6
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                80000
# Model:                         Probit   Df Residuals:                    79998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.3209
# Time:                        14:42:34   Log-Likelihood:                -37508.
# converged:                       True   LL-Null:                       -55230.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1555      0.005     29.462      0.000       0.145       0.166
# V              1.1171      0.007    152.474      0.000       1.103       1.131
# ==============================================================================
# (400000, 12)
# 0.11789823700000003
# 14.316705358840014
# Optimization terminated successfully.
#          Current function value: 0.296123
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5728
# Time:                        14:42:34   Log-Likelihood:                -59225.
# converged:                       True   LL-Null:                   -1.3862e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0216      0.004     -5.231      0.000      -0.030      -0.014
# V              2.1579      0.009    244.021      0.000       2.141       2.175
# ==============================================================================
# (400000, 12)
# 0.23498033899999998
# 14.277516668621193
# Optimization terminated successfully.
#          Current function value: 0.338133
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5122
# Time:                        14:42:35   Log-Likelihood:                -67627.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0480      0.004    -12.382      0.000      -0.056      -0.040
# V              1.8386      0.007    249.968      0.000       1.824       1.853
# ==============================================================================
# (160000, 12)
# 0.06995341125000003
# 14.054489885833641
# Optimization terminated successfully.
#          Current function value: 0.474344
#          Iterations 6
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                80000
# Model:                         Probit   Df Residuals:                    79998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.3128
# Time:                        14:42:35   Log-Likelihood:                -37947.
# converged:                       True   LL-Null:                       -55222.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1454      0.005    -27.739      0.000      -0.156      -0.135
# V              1.0923      0.007    151.633      0.000       1.078       1.106
# ==============================================================================
# (400000, 12)
# 0.07188083900000002
# 14.42875109304651
# Optimization terminated successfully.
#          Current function value: 0.331266
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5221
# Time:                        14:42:35   Log-Likelihood:                -66253.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0049      0.004     -1.250      0.211      -0.013       0.003
# V              1.8812      0.008    250.459      0.000       1.867       1.896
# ==============================================================================
# (400000, 12)
# 0.02004067299999997
# 14.463062820878894
# Optimization terminated successfully.
#          Current function value: 0.374523
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.4597
# Time:                        14:42:36   Log-Likelihood:                -74905.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.004     -0.363      0.717      -0.009       0.006
# V              1.6165      0.006    251.456      0.000       1.604       1.629
# ==============================================================================
# (160000, 12)
# 0.011592921249999995
# 14.580768160528665
# Optimization terminated successfully.
#          Current function value: 0.520725
#          Iterations 6
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                80000
# Model:                         Probit   Df Residuals:                    79998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.2488
# Time:                        14:42:36   Log-Likelihood:                -41658.
# converged:                       True   LL-Null:                       -55452.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0023      0.005     -0.465      0.642      -0.012       0.007
# V              0.9108      0.006    143.021      0.000       0.898       0.923
# ==============================================================================
# (400000, 12)
# -0.05499272999999996
# 14.168084145973767
# Optimization terminated successfully.
#          Current function value: 0.254203
#          Iterations 8
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.6333
# Time:                        14:42:36   Log-Likelihood:                -50841.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0044      0.004     -0.981      0.327      -0.013       0.004
# V              2.6253      0.011    232.989      0.000       2.603       2.647
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.15 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# (400000, 12)
# 0.12188779999999999
# 14.140173986407987
# Optimization terminated successfully.
#          Current function value: 0.304780
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               200000
# Model:                         Probit   Df Residuals:                   199998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.5603
# Time:                        14:42:37   Log-Likelihood:                -60956.
# converged:                       True   LL-Null:                   -1.3863e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.004     -0.308      0.758      -0.009       0.007
# V              2.1126      0.009    244.463      0.000       2.096       2.129
# ==============================================================================
# (160000, 12)
# -0.011725599999999992
# 14.122159088931733
# Optimization terminated successfully.
#          Current function value: 0.398764
#          Iterations 7
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                80000
# Model:                         Probit   Df Residuals:                    79998
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 22 May 2024   Pseudo R-squ.:                  0.4247
# Time:                        14:42:37   Log-Likelihood:                -31901.
# converged:                       True   LL-Null:                       -55452.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.006      0.097      0.922      -0.011       0.012
# V              1.4664      0.009    159.509      0.000       1.448       1.484
# ==============================================================================
